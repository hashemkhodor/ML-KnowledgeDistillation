# %% [markdown]
# ## **Import Libraries**

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img , img_to_array
from tensorflow.keras.layers import Dense , Dropout , Conv2D , MaxPooling2D, Flatten , BatchNormalization


from tensorflow.keras.utils import to_categorical

from keras.callbacks import ReduceLROnPlateau, EarlyStopping

import matplotlib.pyplot as plt
import seaborn as sns # for confusion matrix

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix

import json
import os
import numpy as np

# %% [markdown]
# ## **Load Dataset**

# %%
(x_train , y_train) , (x_test , y_test) = tf.keras.datasets.cifar10.load_data()

# %%
print('Shape of x_train is {}'.format(x_train.shape))
print('Shape of x_test is {}'.format(x_test.shape))
print('Shape of y_train is {}'.format(y_train.shape))
print('Shape of y_test is {}'.format(y_test.shape))
# Out:
# Shape of x_train is (50000, 32, 32, 3)
# Shape of x_test is (10000, 32, 32, 3)
# Shape of y_train is (50000, 1)
# Shape of y_test is (10000, 1)

# %% [markdown]
# ## **Visualization**

# %%
# create a grid of 3x3 images
plt.figure(figsize=(8,8))
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    img = x_train[i]
    plt.imshow(img)

# show the plot
plt.show()

# %% [markdown]
# ## **Preprocess and Splitting**

# %%
def normalize(x):
    x = x.astype('float32')
    x = x/255.0
    return x

datagen = ImageDataGenerator(
                            rotation_range=15,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            horizontal_flip=True,
)

# %%
from sklearn.model_selection import train_test_split
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size = 0.5, random_state = 0)

# %%
x_train = normalize(x_train)
x_test = normalize(x_test)
x_val = normalize(x_val)

y_train = tf.keras.utils.to_categorical(y_train , 10)
y_test = tf.keras.utils.to_categorical(y_test , 10)
y_val  = tf.keras.utils.to_categorical(y_val , 10)

datagen.fit(x_train)

# %%
print(x_train.shape)
print(y_train.shape)
print(y_test.shape)
print(y_val.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)
# (5000, 10)
# (5000, 10)

# %% [markdown]
# ## **Graph**

# %%
def results(model):
  epoch = 50

  epoch_range = range(1, epoch+1)
  plt.plot(epoch_range, history.history['accuracy'])
  plt.plot(epoch_range, history.history['val_accuracy'])
  plt.title('Classification Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='lower right')
  plt.savefig("Classification Accuracy")
  plt.show()

  # Plot training & validation loss values
  plt.plot(epoch_range,history.history['loss'])
  plt.plot(epoch_range, history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='lower right')
  plt.savefig("Model loss")
  plt.show()

# %% [markdown]
# ##**Model**

# %%
division_factor = 4
weight_decay = 1e-4
model = Sequential([
                    Conv2D(64//division_factor, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), input_shape=(32, 32, 3)),
                    BatchNormalization(),
                    Conv2D(64//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.2),

                    Conv2D(128//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    Conv2D(128//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.3),

                    Conv2D(256//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    Conv2D(256//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.4),

                    Flatten(),
                    Dense(256, activation='relu'),
                    BatchNormalization(),
                    Dropout(0.5),
                    Dense(10, activation='softmax')
])

model.summary()
# Out:
# c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 338,970 (1.29 MB)
#  Trainable params: 338,010 (1.29 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
opt =    tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
callbacks = [ ReduceLROnPlateau(monitor='val_loss',
                                patience=10,
                                cooldown=1,
                                verbose=1),
              EarlyStopping(monitor='val_loss',
                            min_delta=1e-4,
                            patience=15)]

# %%
epoch = 50
history = model.fit(datagen.flow(x_train , y_train , batch_size = 64), epochs = epoch, steps_per_epoch=len(x_train)//64, validation_data = (x_val , y_val) , verbose = 1, callbacks=callbacks)
# Out:
# Epoch 1/50
# c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - accuracy: 0.2986 - loss: 2.2797 - val_accuracy: 0.4566 - val_loss: 1.5520 - learning_rate: 0.0010
# Epoch 2/50
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 28s 37ms/step - accuracy: 0.3750 - loss: 1.7965
# C:\Users\hashe\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3750 - loss: 1.7965 - val_accuracy: 0.4556 - val_loss: 1.5582 - learning_rate: 0.0010
# Epoch 3/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.4734 - loss: 1.4644 - val_accuracy: 0.5424 - val_loss: 1.3768 - learning_rate: 0.0010
# Epoch 4/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5469 - loss: 1.2794 - val_accuracy: 0.5460 - val_loss: 1.3672 - learning_rate: 0.0010
# Epoch 5/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.5417 - loss: 1.2855 - val_accuracy: 0.5746 - val_loss: 1.2839 - learning_rate: 0.0010
# Epoch 6/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5312 - loss: 1.3618 - val_accuracy: 0.5792 - val_loss: 1.2533 - learning_rate: 0.0010
# Epoch 7/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.5916 - loss: 1.1556 - val_accuracy: 0.6334 - val_loss: 1.0641 - learning_rate: 0.0010
# Epoch 8/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6250 - loss: 1.1185 - val_accuracy: 0.6268 - val_loss: 1.0851 - learning_rate: 0.0010
# Epoch 9/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 48s 61ms/step - accuracy: 0.6228 - loss: 1.0882 - val_accuracy: 0.6904 - val_loss: 0.9351 - learning_rate: 0.0010
# Epoch 10/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5781 - loss: 1.2000 - val_accuracy: 0.6906 - val_loss: 0.9271 - learning_rate: 0.0010
# Epoch 11/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 47s 59ms/step - accuracy: 0.6468 - loss: 1.0215 - val_accuracy: 0.6880 - val_loss: 0.9350 - learning_rate: 0.0010
# Epoch 12/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7344 - loss: 0.8179 - val_accuracy: 0.6870 - val_loss: 0.9397 - learning_rate: 0.0010
# Epoch 13/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 49s 62ms/step - accuracy: 0.6604 - loss: 0.9921 - val_accuracy: 0.6462 - val_loss: 1.0915 - learning_rate: 0.0010
# Epoch 14/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.8046 - val_accuracy: 0.6398 - val_loss: 1.1070 - learning_rate: 0.0010
# Epoch 15/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.6714 - loss: 0.9726 - val_accuracy: 0.7146 - val_loss: 0.8682 - learning_rate: 0.0010
# Epoch 16/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5938 - loss: 1.2110 - val_accuracy: 0.7144 - val_loss: 0.8679 - learning_rate: 0.0010
# Epoch 17/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.6904 - loss: 0.9296 - val_accuracy: 0.7078 - val_loss: 0.9503 - learning_rate: 0.0010
# Epoch 18/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6562 - loss: 0.9604 - val_accuracy: 0.7092 - val_loss: 0.9367 - learning_rate: 0.0010
# Epoch 19/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.7009 - loss: 0.9084 - val_accuracy: 0.6652 - val_loss: 1.0899 - learning_rate: 0.0010
# Epoch 20/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7344 - loss: 0.8582 - val_accuracy: 0.6750 - val_loss: 1.0565 - learning_rate: 0.0010
# Epoch 21/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 54s 68ms/step - accuracy: 0.7067 - loss: 0.8928 - val_accuracy: 0.7132 - val_loss: 0.8967 - learning_rate: 0.0010
# Epoch 22/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7031 - loss: 0.8650 - val_accuracy: 0.7080 - val_loss: 0.9083 - learning_rate: 0.0010
# Epoch 23/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.7078 - loss: 0.8828 - val_accuracy: 0.7350 - val_loss: 0.8154 - learning_rate: 0.0010
# Epoch 24/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.8253 - val_accuracy: 0.7382 - val_loss: 0.8060 - learning_rate: 0.0010
# Epoch 25/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 53s 67ms/step - accuracy: 0.7199 - loss: 0.8578 - val_accuracy: 0.7500 - val_loss: 0.7782 - learning_rate: 0.0010
# Epoch 26/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7031 - loss: 0.9851 - val_accuracy: 0.7490 - val_loss: 0.7838 - learning_rate: 0.0010
# Epoch 27/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 53s 68ms/step - accuracy: 0.7175 - loss: 0.8523 - val_accuracy: 0.7012 - val_loss: 0.9983 - learning_rate: 0.0010
# Epoch 28/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7500 - loss: 0.8329 - val_accuracy: 0.7086 - val_loss: 0.9691 - learning_rate: 0.0010
# Epoch 29/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.7215 - loss: 0.8542 - val_accuracy: 0.7786 - val_loss: 0.7117 - learning_rate: 0.0010
# Epoch 30/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7344 - loss: 0.8655 - val_accuracy: 0.7806 - val_loss: 0.7057 - learning_rate: 0.0010
# Epoch 31/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 53s 67ms/step - accuracy: 0.7309 - loss: 0.8321 - val_accuracy: 0.7512 - val_loss: 0.7795 - learning_rate: 0.0010
# Epoch 32/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6250 - loss: 1.0941 - val_accuracy: 0.7478 - val_loss: 0.7932 - learning_rate: 0.0010
# Epoch 33/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 51s 66ms/step - accuracy: 0.7307 - loss: 0.8300 - val_accuracy: 0.7424 - val_loss: 0.8322 - learning_rate: 0.0010
# Epoch 34/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7969 - loss: 0.6742 - val_accuracy: 0.7446 - val_loss: 0.8304 - learning_rate: 0.0010
# Epoch 35/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.7396 - loss: 0.8081 - val_accuracy: 0.7598 - val_loss: 0.7681 - learning_rate: 0.0010
# Epoch 36/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8281 - loss: 0.6020 - val_accuracy: 0.7582 - val_loss: 0.7707 - learning_rate: 0.0010
# Epoch 37/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.7420 - loss: 0.8060 - val_accuracy: 0.7702 - val_loss: 0.7472 - learning_rate: 0.0010
# Epoch 38/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8125 - loss: 0.7576 - val_accuracy: 0.7642 - val_loss: 0.7629 - learning_rate: 0.0010
# Epoch 39/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 52s 67ms/step - accuracy: 0.7396 - loss: 0.8136 - val_accuracy: 0.7612 - val_loss: 0.7699 - learning_rate: 0.0010
# Epoch 40/50
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.6406 - loss: 1.1028
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6406 - loss: 1.1028 - val_accuracy: 0.7618 - val_loss: 0.7700 - learning_rate: 0.0010
# Epoch 41/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.7526 - loss: 0.7745 - val_accuracy: 0.7736 - val_loss: 0.7234 - learning_rate: 1.0000e-04
# Epoch 42/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7656 - loss: 0.7417 - val_accuracy: 0.7734 - val_loss: 0.7245 - learning_rate: 1.0000e-04
# Epoch 43/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.7609 - loss: 0.7436 - val_accuracy: 0.7846 - val_loss: 0.6904 - learning_rate: 1.0000e-04
# Epoch 44/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8281 - loss: 0.5787 - val_accuracy: 0.7840 - val_loss: 0.6907 - learning_rate: 1.0000e-04
# Epoch 45/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 53s 68ms/step - accuracy: 0.7674 - loss: 0.7378 - val_accuracy: 0.7876 - val_loss: 0.6756 - learning_rate: 1.0000e-04
# Epoch 46/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7812 - loss: 0.6455 - val_accuracy: 0.7876 - val_loss: 0.6754 - learning_rate: 1.0000e-04
# Epoch 47/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.7689 - loss: 0.7373 - val_accuracy: 0.7942 - val_loss: 0.6677 - learning_rate: 1.0000e-04
# Epoch 48/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7812 - loss: 0.6729 - val_accuracy: 0.7944 - val_loss: 0.6683 - learning_rate: 1.0000e-04
# Epoch 49/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.7692 - loss: 0.7242 - val_accuracy: 0.7814 - val_loss: 0.7054 - learning_rate: 1.0000e-04
# Epoch 50/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7812 - loss: 0.5979 - val_accuracy: 0.7806 - val_loss: 0.7051 - learning_rate: 1.0000e-04

# %% [markdown]
# ## **Results and Save**

# %%
acc = model.evaluate(x_test , y_test)
print("test set loss : " , acc[0])
print("test set accuracy :", acc[1]*100)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7700 - loss: 0.7280
# test set loss :  0.7123436331748962
# test set accuracy : 77.70000100135803

# %%
results(model)

# %%
from random import randint
def saveModel(model, history: dict, dir_prefix: str = r"..\NoteBook\NonDistilledStudent", dir_output:str=r"NonDistilledStudent-1"):
    """
    Creates a directory and saves the model in .h5 format, training history as a JSON file,
    and training and test datasets as .npy files.

    Args:
    model (tf.keras.Model): The trained Keras model to save.
    history (dict): Dictionary containing the training history.
    x_test, y_test, x_train, y_train (numpy.ndarray): Datasets to save.
    output_dir (str, optional): The directory to save all files. Defaults to "TeacherModel".

    Returns:
    bool: True if all files are saved successfully, False if an error occurs.
    """
    try:        
    # Create the directory if it does not exist
        dir_path = os.path.join(dir_prefix, dir_output)
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)
            
        history_path = os.path.join(dir_path, "history.json")
        with open(history_path, 'w') as f:
            f.write(json.dumps(history,indent=4))
            f.close()

        model_path = os.path.join(dir_path, "model.keras")
        model.save(model_path)
        

        return True
    except Exception as e:
        print(type(e))
        print(f"An error occurred: {e}")
        
        return False

# %%
# print(history.history)
index = 2
print(saveModel(model,history.history,dir_output=f"NonDistilledStudent-{index}"))
# Out:
# True
