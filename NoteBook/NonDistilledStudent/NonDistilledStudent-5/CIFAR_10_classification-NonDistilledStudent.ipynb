# %% [markdown]
# ## **Import Libraries**

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img , img_to_array
from tensorflow.keras.layers import Dense , Dropout , Conv2D , MaxPooling2D, Flatten , BatchNormalization


from tensorflow.keras.utils import to_categorical

from keras.callbacks import ReduceLROnPlateau, EarlyStopping

import matplotlib.pyplot as plt
import seaborn as sns # for confusion matrix

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix

import json
import os
import numpy as np

# %% [markdown]
# ## **Load Dataset**

# %%
(x_train , y_train) , (x_test , y_test) = tf.keras.datasets.cifar10.load_data()

# %%
print('Shape of x_train is {}'.format(x_train.shape))
print('Shape of x_test is {}'.format(x_test.shape))
print('Shape of y_train is {}'.format(y_train.shape))
print('Shape of y_test is {}'.format(y_test.shape))
# Out:
# Shape of x_train is (50000, 32, 32, 3)
# Shape of x_test is (10000, 32, 32, 3)
# Shape of y_train is (50000, 1)
# Shape of y_test is (10000, 1)

# %% [markdown]
# ## **Visualization**

# %%
# create a grid of 3x3 images
plt.figure(figsize=(8,8))
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    img = x_train[i]
    plt.imshow(img)

# show the plot
plt.show()

# %% [markdown]
# ## **Preprocess and Splitting**

# %%
def normalize(x):
    x = x.astype('float32')
    x = x/255.0
    return x

datagen = ImageDataGenerator(
                            rotation_range=15,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            horizontal_flip=True,
)

# %%
from sklearn.model_selection import train_test_split
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size = 0.5, random_state = 0)

# %%
x_train = normalize(x_train)
x_test = normalize(x_test)
x_val = normalize(x_val)

y_train = tf.keras.utils.to_categorical(y_train , 10)
y_test = tf.keras.utils.to_categorical(y_test , 10)
y_val  = tf.keras.utils.to_categorical(y_val , 10)

datagen.fit(x_train)

# %%
print(x_train.shape)
print(y_train.shape)
print(y_test.shape)
print(y_val.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)
# (5000, 10)
# (5000, 10)

# %% [markdown]
# ## **Graph**

# %%
def results(model):
  epoch = 50

  epoch_range = range(1, epoch+1)
  plt.plot(epoch_range, history.history['accuracy'])
  plt.plot(epoch_range, history.history['val_accuracy'])
  plt.title('Classification Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='lower right')
  plt.savefig("Classification Accuracy")
  plt.show()

  # Plot training & validation loss values
  plt.plot(epoch_range,history.history['loss'])
  plt.plot(epoch_range, history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='lower right')
  plt.savefig("Model loss")
  plt.show()

# %% [markdown]
# ##**Model**

# %%
division_factor = 4
weight_decay = 1e-4
model = Sequential([
                    Conv2D(64//division_factor, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), input_shape=(32, 32, 3)),
                    BatchNormalization(),
                    Conv2D(64//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.2),

                    Conv2D(128//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    Conv2D(128//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.3),

                    Conv2D(256//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    Conv2D(256//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.4),

                    Flatten(),
                    Dense(256, activation='relu'),
                    BatchNormalization(),
                    Dropout(0.5),
                    Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 32, 32, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 32, 32, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 32, 32, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 16, 16, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 16, 16, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 8, 8, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 8, 8, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 338,970 (1.29 MB)
#  Trainable params: 338,010 (1.29 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
opt =    tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
callbacks = [ ReduceLROnPlateau(monitor='val_loss',
                                patience=10,
                                cooldown=1,
                                verbose=1),
              EarlyStopping(monitor='val_loss',
                            min_delta=1e-4,
                            patience=15)]

# %%
epoch = 50
history = model.fit(datagen.flow(x_train , y_train , batch_size = 64), epochs = epoch, steps_per_epoch=len(x_train)//64, validation_data = (x_val , y_val) , verbose = 1, callbacks=callbacks)
# Out:
# Epoch 1/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 37s 43ms/step - accuracy: 0.3012 - loss: 2.2376 - val_accuracy: 0.4480 - val_loss: 1.5689 - learning_rate: 0.0010
# Epoch 2/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5312 - loss: 1.4525 - val_accuracy: 0.4464 - val_loss: 1.5629 - learning_rate: 0.0010
# Epoch 3/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.4813 - loss: 1.4493 - val_accuracy: 0.5644 - val_loss: 1.3003 - learning_rate: 0.0010
# Epoch 4/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5938 - loss: 1.2474 - val_accuracy: 0.5650 - val_loss: 1.2969 - learning_rate: 0.0010
# Epoch 5/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.5604 - loss: 1.2559 - val_accuracy: 0.5730 - val_loss: 1.2851 - learning_rate: 0.0010
# Epoch 6/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5312 - loss: 1.2265 - val_accuracy: 0.5702 - val_loss: 1.2932 - learning_rate: 0.0010
# Epoch 7/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.5950 - loss: 1.1543 - val_accuracy: 0.6688 - val_loss: 0.9571 - learning_rate: 0.0010
# Epoch 8/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6250 - loss: 1.0767 - val_accuracy: 0.6718 - val_loss: 0.9551 - learning_rate: 0.0010
# Epoch 9/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.6234 - loss: 1.0751 - val_accuracy: 0.6226 - val_loss: 1.1336 - learning_rate: 0.0010
# Epoch 10/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6406 - loss: 1.0176 - val_accuracy: 0.6298 - val_loss: 1.1117 - learning_rate: 0.0010
# Epoch 11/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 48s 61ms/step - accuracy: 0.6510 - loss: 1.0208 - val_accuracy: 0.6582 - val_loss: 1.0490 - learning_rate: 0.0010
# Epoch 12/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5000 - loss: 1.4027 - val_accuracy: 0.6560 - val_loss: 1.0570 - learning_rate: 0.0010
# Epoch 13/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.6695 - loss: 0.9719 - val_accuracy: 0.6588 - val_loss: 1.0122 - learning_rate: 0.0010
# Epoch 14/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7812 - loss: 0.7289 - val_accuracy: 0.6582 - val_loss: 1.0131 - learning_rate: 0.0010
# Epoch 15/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 66s 85ms/step - accuracy: 0.6760 - loss: 0.9465 - val_accuracy: 0.7026 - val_loss: 0.9316 - learning_rate: 0.0010
# Epoch 16/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7500 - loss: 0.8334 - val_accuracy: 0.7038 - val_loss: 0.9370 - learning_rate: 0.0010
# Epoch 17/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.6916 - loss: 0.9217 - val_accuracy: 0.7026 - val_loss: 0.8977 - learning_rate: 0.0010
# Epoch 18/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7344 - loss: 0.7688 - val_accuracy: 0.6970 - val_loss: 0.9132 - learning_rate: 0.0010
# Epoch 19/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.7042 - loss: 0.8971 - val_accuracy: 0.7452 - val_loss: 0.7867 - learning_rate: 0.0010
# Epoch 20/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7344 - loss: 0.9129 - val_accuracy: 0.7476 - val_loss: 0.7866 - learning_rate: 0.0010
# Epoch 21/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 50s 63ms/step - accuracy: 0.7043 - loss: 0.8793 - val_accuracy: 0.7230 - val_loss: 0.8533 - learning_rate: 0.0010
# Epoch 22/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7500 - loss: 0.9768 - val_accuracy: 0.7236 - val_loss: 0.8515 - learning_rate: 0.0010
# Epoch 23/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.7108 - loss: 0.8742 - val_accuracy: 0.7058 - val_loss: 0.8942 - learning_rate: 0.0010
# Epoch 24/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6719 - loss: 0.9596 - val_accuracy: 0.7026 - val_loss: 0.9068 - learning_rate: 0.0010
# Epoch 25/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 50s 63ms/step - accuracy: 0.7213 - loss: 0.8509 - val_accuracy: 0.7276 - val_loss: 0.8667 - learning_rate: 0.0010
# Epoch 26/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7344 - loss: 0.9939 - val_accuracy: 0.7242 - val_loss: 0.8782 - learning_rate: 0.0010
# Epoch 27/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.7192 - loss: 0.8531 - val_accuracy: 0.7382 - val_loss: 0.8131 - learning_rate: 0.0010
# Epoch 28/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7969 - loss: 0.6485 - val_accuracy: 0.7344 - val_loss: 0.8251 - learning_rate: 0.0010
# Epoch 29/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 46s 59ms/step - accuracy: 0.7240 - loss: 0.8391 - val_accuracy: 0.7532 - val_loss: 0.7865 - learning_rate: 0.0010
# Epoch 30/50
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7344 - loss: 0.7292
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7344 - loss: 0.7292 - val_accuracy: 0.7474 - val_loss: 0.7949 - learning_rate: 0.0010
# Epoch 31/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 46s 59ms/step - accuracy: 0.7436 - loss: 0.7935 - val_accuracy: 0.7826 - val_loss: 0.6910 - learning_rate: 1.0000e-04
# Epoch 32/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6094 - loss: 0.9421 - val_accuracy: 0.7824 - val_loss: 0.6915 - learning_rate: 1.0000e-04
# Epoch 33/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 47s 60ms/step - accuracy: 0.7532 - loss: 0.7619 - val_accuracy: 0.7888 - val_loss: 0.6748 - learning_rate: 1.0000e-04
# Epoch 34/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9062 - loss: 0.4957 - val_accuracy: 0.7886 - val_loss: 0.6744 - learning_rate: 1.0000e-04
# Epoch 35/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.7571 - loss: 0.7570 - val_accuracy: 0.7892 - val_loss: 0.6753 - learning_rate: 1.0000e-04
# Epoch 36/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6250 - loss: 0.9562 - val_accuracy: 0.7884 - val_loss: 0.6757 - learning_rate: 1.0000e-04
# Epoch 37/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 54s 68ms/step - accuracy: 0.7565 - loss: 0.7506 - val_accuracy: 0.7914 - val_loss: 0.6772 - learning_rate: 1.0000e-04
# Epoch 38/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7656 - loss: 0.7725 - val_accuracy: 0.7912 - val_loss: 0.6779 - learning_rate: 1.0000e-04
# Epoch 39/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 85s 108ms/step - accuracy: 0.7604 - loss: 0.7440 - val_accuracy: 0.7964 - val_loss: 0.6642 - learning_rate: 1.0000e-04
# Epoch 40/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7031 - loss: 0.8790 - val_accuracy: 0.7966 - val_loss: 0.6644 - learning_rate: 1.0000e-04
# Epoch 41/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.7583 - loss: 0.7440 - val_accuracy: 0.8014 - val_loss: 0.6466 - learning_rate: 1.0000e-04
# Epoch 42/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8594 - loss: 0.6146 - val_accuracy: 0.8016 - val_loss: 0.6468 - learning_rate: 1.0000e-04
# Epoch 43/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 47s 60ms/step - accuracy: 0.7639 - loss: 0.7348 - val_accuracy: 0.7888 - val_loss: 0.6843 - learning_rate: 1.0000e-04
# Epoch 44/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7812 - loss: 0.6968 - val_accuracy: 0.7890 - val_loss: 0.6846 - learning_rate: 1.0000e-04
# Epoch 45/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.7653 - loss: 0.7260 - val_accuracy: 0.8008 - val_loss: 0.6407 - learning_rate: 1.0000e-04
# Epoch 46/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7500 - loss: 0.7199 - val_accuracy: 0.8008 - val_loss: 0.6408 - learning_rate: 1.0000e-04
# Epoch 47/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 72s 91ms/step - accuracy: 0.7664 - loss: 0.7269 - val_accuracy: 0.8004 - val_loss: 0.6575 - learning_rate: 1.0000e-04
# Epoch 48/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7500 - loss: 0.8344 - val_accuracy: 0.8016 - val_loss: 0.6566 - learning_rate: 1.0000e-04
# Epoch 49/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.7687 - loss: 0.7242 - val_accuracy: 0.7978 - val_loss: 0.6472 - learning_rate: 1.0000e-04
# Epoch 50/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8281 - loss: 0.5645 - val_accuracy: 0.7978 - val_loss: 0.6466 - learning_rate: 1.0000e-04

# %% [markdown]
# ## **Results and Save**

# %%
acc = model.evaluate(x_test , y_test)
print("test set loss : " , acc[0])
print("test set accuracy :", acc[1]*100)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7872 - loss: 0.6615
# test set loss :  0.6517167687416077
# test set accuracy : 79.07999753952026

# %%
results(model)

# %%
from random import randint
def saveModel(model, history: dict, dir_prefix: str = r"..\NoteBook\NonDistilledStudent", dir_output:str=r"NonDistilledStudent-1"):
    """
    Creates a directory and saves the model in .h5 format, training history as a JSON file,
    and training and test datasets as .npy files.

    Args:
    model (tf.keras.Model): The trained Keras model to save.
    history (dict): Dictionary containing the training history.
    x_test, y_test, x_train, y_train (numpy.ndarray): Datasets to save.
    output_dir (str, optional): The directory to save all files. Defaults to "TeacherModel".

    Returns:
    bool: True if all files are saved successfully, False if an error occurs.
    """
    try:        
    # Create the directory if it does not exist
        dir_path = os.path.join(dir_prefix, dir_output)
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)
            
        history_path = os.path.join(dir_path, "history.json")
        with open(history_path, 'w') as f:
            f.write(json.dumps(history,indent=4))
            f.close()

        model_path = os.path.join(dir_path, "model.keras")
        model.save(model_path)
        

        return True
    except Exception as e:
        print(type(e))
        print(f"An error occurred: {e}")
        
        return False

# %%
# print(history.history)
index = 3
print(saveModel(model,history.history,dir_output=f"NonDistilledStudent-{index}"))
# Out:
# True
