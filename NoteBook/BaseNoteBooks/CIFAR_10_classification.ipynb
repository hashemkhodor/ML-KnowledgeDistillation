# %% [markdown]
# ## **Import Libraries**

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img , img_to_array
from tensorflow.keras.layers import Dense , Dropout , Conv2D , MaxPooling2D, Flatten , BatchNormalization


from tensorflow.keras.utils import to_categorical

from keras.callbacks import ReduceLROnPlateau, EarlyStopping

import matplotlib.pyplot as plt
import seaborn as sns # for confusion matrix

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix

import json
import os
import numpy as np

# %% [markdown]
# ## **Load Dataset**

# %%
(x_train , y_train) , (x_test , y_test) = tf.keras.datasets.cifar10.load_data()

# %%
print('Shape of x_train is {}'.format(x_train.shape))
print('Shape of x_test is {}'.format(x_test.shape))
print('Shape of y_train is {}'.format(y_train.shape))
print('Shape of y_test is {}'.format(y_test.shape))
# Out:
# Shape of x_train is (50000, 32, 32, 3)
# Shape of x_test is (10000, 32, 32, 3)
# Shape of y_train is (50000, 1)
# Shape of y_test is (10000, 1)

# %% [markdown]
# ## **Visualization**

# %%
# create a grid of 3x3 images
plt.figure(figsize=(8,8))
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    img = x_train[i]
    plt.imshow(img)
    
# show the plot
plt.show()

# %% [markdown]
# ## **Preprocess and Splitting**

# %%
def normalize(x):
    x = x.astype('float32')
    x = x/255.0
    return x

datagen = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
)

# %% [markdown]
# ### Split Data

# %%
from sklearn.model_selection import train_test_split
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size = 0.5, random_state = 0) # seed for fixing the x_test and y_test

# %%
x_train = normalize(x_train)
x_test = normalize(x_test)
x_val = normalize(x_val)

y_train = tf.keras.utils.to_categorical(y_train , 10) # one hot encoding
y_test = tf.keras.utils.to_categorical(y_test , 10)
y_val  = tf.keras.utils.to_categorical(y_val , 10)

datagen.fit(x_train)

# %%
print(x_train.shape)
print(y_train.shape)
print(y_test.shape)
print(y_val.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)
# (5000, 10)
# (5000, 10)

# %% [markdown]
# ## **Model**

# %%
weight_decay = 1e-4
model = Sequential([
    Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), input_shape=(32, 32, 3)),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.2),

    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),

    Conv2D(256, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    Conv2D(256, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.4),

    Flatten(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    # Dense(10, activation='softmax')                    
    Dense(10, name="outputs")
])

model.summary()
# Out:
# c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\Venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,048,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ outputs (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,201,418 (8.40 MB)
#  Trainable params: 2,199,114 (8.39 MB)
#  Non-trainable params: 2,304 (9.00 KB)

# %% [markdown]
# ### Training

# %%
opt =    tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999)

model.compile(
    optimizer=opt, 
    # loss='categorical_crossentropy', 
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'])

# %%
callbacks = [ ReduceLROnPlateau(monitor='val_loss', 
                                patience=10,
                                cooldown=1,
                                verbose=1),
              EarlyStopping(monitor='val_loss',
                            min_delta=1e-4,
                            patience=15)]

# %%
epoch = 50
history = model.fit(datagen.flow(x_train , y_train , batch_size = 64), epochs = epoch, steps_per_epoch=len(x_train)//64, validation_data = (x_val , y_val) , verbose = 1, callbacks=callbacks)
# Out:
# Epoch 1/50
# c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\Venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 268s 337ms/step - accuracy: 0.3468 - loss: 2.1220 - val_accuracy: 0.5508 - val_loss: 1.3900 - learning_rate: 0.0010
# Epoch 2/50
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 3:51 297ms/step - accuracy: 0.5781 - loss: 1.3792
# C:\Users\hashe\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.5781 - loss: 1.3792 - val_accuracy: 0.5554 - val_loss: 1.3750 - learning_rate: 0.0010
# Epoch 3/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 264s 338ms/step - accuracy: 0.5792 - loss: 1.2723 - val_accuracy: 0.6554 - val_loss: 1.0749 - learning_rate: 0.0010
# Epoch 4/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.6562 - loss: 1.1793 - val_accuracy: 0.6416 - val_loss: 1.1107 - learning_rate: 0.0010
# Epoch 5/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 282s 361ms/step - accuracy: 0.6725 - loss: 1.0271 - val_accuracy: 0.6362 - val_loss: 1.1986 - learning_rate: 0.0010
# Epoch 6/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.7500 - loss: 0.9263 - val_accuracy: 0.6194 - val_loss: 1.2641 - learning_rate: 0.0010
# Epoch 7/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 243s 311ms/step - accuracy: 0.7190 - loss: 0.9329 - val_accuracy: 0.7544 - val_loss: 0.8613 - learning_rate: 0.0010
# Epoch 8/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.7344 - loss: 0.9847 - val_accuracy: 0.7568 - val_loss: 0.8540 - learning_rate: 0.0010
# Epoch 9/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 253s 324ms/step - accuracy: 0.7458 - loss: 0.8819 - val_accuracy: 0.7812 - val_loss: 0.8094 - learning_rate: 0.0010
# Epoch 10/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7812 - loss: 0.7661 - val_accuracy: 0.7850 - val_loss: 0.7987 - learning_rate: 0.0010
# Epoch 11/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 266s 340ms/step - accuracy: 0.7681 - loss: 0.8439 - val_accuracy: 0.7960 - val_loss: 0.7975 - learning_rate: 0.0010
# Epoch 12/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.7656 - loss: 0.7899 - val_accuracy: 0.7948 - val_loss: 0.7924 - learning_rate: 0.0010
# Epoch 13/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 268s 343ms/step - accuracy: 0.7805 - loss: 0.8252 - val_accuracy: 0.7344 - val_loss: 0.9918 - learning_rate: 0.0010
# Epoch 14/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.7812 - loss: 0.7390 - val_accuracy: 0.7328 - val_loss: 0.9903 - learning_rate: 0.0010
# Epoch 15/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 264s 338ms/step - accuracy: 0.7896 - loss: 0.8253 - val_accuracy: 0.8114 - val_loss: 0.7941 - learning_rate: 0.0010
# Epoch 16/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.8750 - loss: 0.5718 - val_accuracy: 0.8114 - val_loss: 0.7873 - learning_rate: 0.0010
# Epoch 17/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 265s 339ms/step - accuracy: 0.7976 - loss: 0.8147 - val_accuracy: 0.7762 - val_loss: 0.9335 - learning_rate: 0.0010
# Epoch 18/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.8750 - loss: 0.8014 - val_accuracy: 0.7746 - val_loss: 0.9432 - learning_rate: 0.0010
# Epoch 19/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 266s 340ms/step - accuracy: 0.8083 - loss: 0.8073 - val_accuracy: 0.8382 - val_loss: 0.7474 - learning_rate: 0.0010
# Epoch 20/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8438 - loss: 0.7030 - val_accuracy: 0.8400 - val_loss: 0.7382 - learning_rate: 0.0010
# Epoch 21/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 269s 344ms/step - accuracy: 0.8133 - loss: 0.8019 - val_accuracy: 0.7870 - val_loss: 0.9197 - learning_rate: 0.0010
# Epoch 22/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.6719 - loss: 1.1496 - val_accuracy: 0.7934 - val_loss: 0.9036 - learning_rate: 0.0010
# Epoch 23/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 266s 340ms/step - accuracy: 0.8193 - loss: 0.8034 - val_accuracy: 0.8220 - val_loss: 0.8250 - learning_rate: 0.0010
# Epoch 24/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.8281 - loss: 0.7622 - val_accuracy: 0.8206 - val_loss: 0.8335 - learning_rate: 0.0010
# Epoch 25/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 268s 343ms/step - accuracy: 0.8265 - loss: 0.7876 - val_accuracy: 0.8176 - val_loss: 0.8300 - learning_rate: 0.0010
# Epoch 26/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.7969 - loss: 0.8487 - val_accuracy: 0.8128 - val_loss: 0.8488 - learning_rate: 0.0010
# Epoch 27/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 267s 341ms/step - accuracy: 0.8290 - loss: 0.7759 - val_accuracy: 0.8500 - val_loss: 0.7431 - learning_rate: 0.0010
# Epoch 28/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.7969 - loss: 0.7656 - val_accuracy: 0.8488 - val_loss: 0.7448 - learning_rate: 0.0010
# Epoch 29/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 276s 353ms/step - accuracy: 0.8332 - loss: 0.7852 - val_accuracy: 0.8242 - val_loss: 0.8317 - learning_rate: 0.0010
# Epoch 30/50
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 4:30 347ms/step - accuracy: 0.8125 - loss: 0.7865
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8125 - loss: 0.7865 - val_accuracy: 0.8186 - val_loss: 0.8459 - learning_rate: 0.0010
# Epoch 31/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 278s 356ms/step - accuracy: 0.8545 - loss: 0.7240 - val_accuracy: 0.8724 - val_loss: 0.6636 - learning_rate: 1.0000e-04
# Epoch 32/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8750 - loss: 0.6720 - val_accuracy: 0.8726 - val_loss: 0.6640 - learning_rate: 1.0000e-04
# Epoch 33/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 277s 355ms/step - accuracy: 0.8690 - loss: 0.6620 - val_accuracy: 0.8722 - val_loss: 0.6556 - learning_rate: 1.0000e-04
# Epoch 34/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.7656 - loss: 0.7804 - val_accuracy: 0.8726 - val_loss: 0.6554 - learning_rate: 1.0000e-04
# Epoch 35/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 280s 358ms/step - accuracy: 0.8755 - loss: 0.6411 - val_accuracy: 0.8722 - val_loss: 0.6551 - learning_rate: 1.0000e-04
# Epoch 36/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8906 - loss: 0.6274 - val_accuracy: 0.8722 - val_loss: 0.6556 - learning_rate: 1.0000e-04
# Epoch 37/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 278s 355ms/step - accuracy: 0.8797 - loss: 0.6208 - val_accuracy: 0.8772 - val_loss: 0.6309 - learning_rate: 1.0000e-04
# Epoch 38/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8906 - loss: 0.5245 - val_accuracy: 0.8772 - val_loss: 0.6312 - learning_rate: 1.0000e-04
# Epoch 39/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 274s 350ms/step - accuracy: 0.8818 - loss: 0.6053 - val_accuracy: 0.8784 - val_loss: 0.6151 - learning_rate: 1.0000e-04
# Epoch 40/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8125 - loss: 0.7245 - val_accuracy: 0.8786 - val_loss: 0.6154 - learning_rate: 1.0000e-04
# Epoch 41/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 277s 355ms/step - accuracy: 0.8842 - loss: 0.5905 - val_accuracy: 0.8782 - val_loss: 0.6125 - learning_rate: 1.0000e-04
# Epoch 42/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9219 - loss: 0.5057 - val_accuracy: 0.8780 - val_loss: 0.6123 - learning_rate: 1.0000e-04
# Epoch 43/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 275s 352ms/step - accuracy: 0.8898 - loss: 0.5698 - val_accuracy: 0.8864 - val_loss: 0.5914 - learning_rate: 1.0000e-04
# Epoch 44/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8906 - loss: 0.6224 - val_accuracy: 0.8862 - val_loss: 0.5914 - learning_rate: 1.0000e-04
# Epoch 45/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 284s 364ms/step - accuracy: 0.8911 - loss: 0.5625 - val_accuracy: 0.8854 - val_loss: 0.5853 - learning_rate: 1.0000e-04
# Epoch 46/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8594 - loss: 0.7119 - val_accuracy: 0.8848 - val_loss: 0.5852 - learning_rate: 1.0000e-04
# Epoch 47/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 280s 358ms/step - accuracy: 0.8936 - loss: 0.5491 - val_accuracy: 0.8928 - val_loss: 0.5611 - learning_rate: 1.0000e-04
# Epoch 48/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9219 - loss: 0.5139 - val_accuracy: 0.8932 - val_loss: 0.5609 - learning_rate: 1.0000e-04
# Epoch 49/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 272s 348ms/step - accuracy: 0.8920 - loss: 0.5442 - val_accuracy: 0.8840 - val_loss: 0.5764 - learning_rate: 1.0000e-04
# Epoch 50/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8438 - loss: 0.7628 - val_accuracy: 0.8846 - val_loss: 0.5763 - learning_rate: 1.0000e-04

# %% [markdown]
# ## **Results and Save**

# %% [markdown]
# ### **Results**

# %%
def plot_results(model):
    epoch = max(
        [
            len(history.history[key]) for key in ["accuracy","val_accuracy","loss","val_loss"]
        ]
        )
    epoch_range = range(1, epoch+1)
    plt.plot(epoch_range, history.history['accuracy'])
    plt.plot(epoch_range, history.history['val_accuracy'])
    plt.title('Classification Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='lower right')
    plt.savefig("Classification Accuracy")
    plt.show()

    # Plot training & validation loss values
    plt.plot(epoch_range,history.history['loss'])
    plt.plot(epoch_range, history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='lower right')
    plt.savefig("Model loss")
    plt.show()

# %%
def plot_confusion_matrix(y_true, y_pred, classes, cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    
    Args:
    y_true (list or array): True labels.
    y_pred (list or array): Predicted labels.
    classes (list): List of class names for labeling the axes in the plot.
    cmap (matplotlib.colors.Colormap, optional): Colormap to be used for the plot. Defaults to plt.cm.Blues.
    
    Returns:
    None: Displays the confusion matrix.
    """
    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap=cmap, xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

def evaluate_model_performance(y_true, y_pred):
    """
    Evaluate model performance metrics including accuracy, precision, recall, and F1 score.
    
    Args:
    y_true (list or array): Actual true labels.
    y_pred (list or array): Predicted labels from the model.
    
    Returns:
    dict: A dictionary containing all the scores.
    """
    scores = {}
    scores['accuracy'] = accuracy_score(y_true, y_pred)
    scores['precision'] = precision_score(y_true, y_pred, average='macro')  # Use 'macro' for unweighted mean
    scores['recall'] = recall_score(y_true, y_pred, average='macro')
    scores['f1_score'] = f1_score(y_true, y_pred, average='macro')
    
    return scores

# %%
acc = model.evaluate(x_test , y_test)
print("test set loss : " , acc[0])
print("test set accuracy :", acc[1]*100)


# model2 = load_model("Teacher-1/model.h5")
# acc = model2.evaluate(x_test , y_test)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8857 - loss: 0.5485
# test set loss :  0.5469261407852173
# test set accuracy : 89.0999972820282

# %%
plot_results(model)

# %% [markdown]
# ### Confusion Matrix

# %%
# Calculate the confusion matrix
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Make predictions
y_pred = model.predict(x_test)
# Convert predictions from probabilities to labels if necessary
y_pred_labels = np.argmax(y_pred, axis=1)

# Assuming y_test is also in a one-hot encoded format, convert it to labels
y_true_labels = np.argmax(y_test, axis=1)
conf_matrix = plot_confusion_matrix(y_true_labels, y_pred_labels,class_names)
# print("Confusion Matrix:")
# print(conf_matrix)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step

# %% [markdown]
# ### Other Scores

# %%
# Evaluate other performance metrics
performance_scores = evaluate_model_performance(y_true_labels, y_pred_labels)
print("Performance Scores:")
for score_name, score_value in performance_scores.items():
    print(f"{score_name.capitalize()}: {score_value}")
# Out:
# Performance Scores:
# Accuracy: 0.891
# Precision: 0.8918349601172316
# Recall: 0.8917150765046788
# F1_score: 0.8903992423520333

# %% [markdown]
# ### Save

# %%
def save_model(model, history: dict, x_test, y_test, x_train, y_train, output_dir: str = "TeacherModel"):
    """
    Creates a directory and saves the model in .h5 format, training history as a JSON file,
    and training and test datasets as .npy files.

    Args:
    model (tf.keras.Model): The trained Keras model to save.
    history (dict): Dictionary containing the training history.
    x_test, y_test, x_train, y_train (numpy.ndarray): Datasets to save.
    output_dir (str, optional): The directory to save all files. Defaults to "TeacherModel".

    Returns:
    bool: True if all files are saved successfully, False if an error occurs.
    """
    try:        
        # Create the directory if it does not exist
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        # Save the model in HDF5 format
        model_path = os.path.join(output_dir, "model.h5")
        model.save(model_path)

        # Save the history
        history_path = os.path.join(output_dir, "history.json")
        with open(history_path, 'w') as f:
            json.dump(history, f)

        # Save the datasets
        np.save(os.path.join(output_dir, "x_test.npy"), x_test)
        np.save(os.path.join(output_dir, "y_test.npy"), y_test)
        np.save(os.path.join(output_dir, "x_train.npy"), x_train)
        np.save(os.path.join(output_dir, "y_train.npy"), y_train)

        return True
    except Exception as e:
        print(f"An error occurred: {e}")
        return False

# %%
# print(history.history)
print(save_model(model,history.history,x_test,y_test,x_train,y_train,"Teacher-2"))
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# True
