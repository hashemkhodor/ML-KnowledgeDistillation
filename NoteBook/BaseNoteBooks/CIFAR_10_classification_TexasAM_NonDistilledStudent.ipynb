# %% [markdown]
# ## **Import Libraries**

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img , img_to_array
from tensorflow.keras.layers import Dense , Dropout , Conv2D , MaxPooling2D, Flatten , BatchNormalization

from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Load Dataset**

# %%
(x_train , y_train) , (x_test , y_test) = tf.keras.datasets.cifar10.load_data()

# %%
print('Shape of x_train is {}'.format(x_train.shape))
print('Shape of x_test is {}'.format(x_test.shape))
print('Shape of y_train is {}'.format(y_train.shape))
print('Shape of y_test is {}'.format(y_test.shape))
# Out:
# Shape of x_train is (50000, 32, 32, 3)
# Shape of x_test is (10000, 32, 32, 3)
# Shape of y_train is (50000, 1)
# Shape of y_test is (10000, 1)

# %% [markdown]
# ## **Visualization**

# %%
# create a grid of 3x3 images
plt.figure(figsize=(8,8))
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    img = x_train[i]
    plt.imshow(img)

# show the plot
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(15,5))
# Count plot for training set
sns.countplot(y_train.ravel(), ax=axs[0])
axs[0].set_title('Distribution of training data')
axs[0].set_xlabel('Classes')
# Count plot for testing set
sns.countplot(y_test.ravel(), ax=axs[1])
axs[1].set_title('Distribution of Testing data')
axs[1].set_xlabel('Classes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 fig, axs = plt.subplots(1,2,figsize=(15,5))
#       2 # Count plot for training set
# ----> 3 sns.countplot(y_train.ravel(), ax=axs[0])
#       4 axs[0].set_title('Distribution of training data')
#       5 axs[0].set_xlabel('Classes')
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\seaborn\categorical.py:2687, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2673 aggregator = EstimateAggregator("sum", errorbar=None)
#    2675 p.plot_bars(
#    2676     aggregator=aggregator,
#    2677     dodge=dodge,
#    (...)
#    2684     plot_kws=kwargs,
#    2685 )
# -> 2687 p._add_axis_labels(ax)
#    2688 p._adjust_cat_axis(ax, axis=p.orient)
#    2690 return ax
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\seaborn\_base.py:1196, in VectorPlotter._add_axis_labels(self, ax, default_x, default_y)
#    1191 # TODO ax could default to None and use attached axes if present
#    1192 # but what to do about the case of facets? Currently using FacetGrid's
#    1193 # set_axis_labels method, which doesn't add labels to the interior even
#    1194 # when the axes are not shared. Maybe that makes sense?
#    1195 if not ax.get_xlabel():
# -> 1196     x_visible = any(t.get_visible() for t in ax.get_xticklabels())
#    1197     ax.set_xlabel(self.variables.get("x", default_x), visible=x_visible)
#    1198 if not ax.get_ylabel():
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\axis.py:1502, in Axis.get_ticklabels(self, minor, which)
#    1500 if minor:
#    1501     return self.get_minorticklabels()
# -> 1502 return self.get_majorticklabels()
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\axis.py:1459, in Axis.get_majorticklabels(self)
#    1457 def get_majorticklabels(self):
#    1458     """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1459     self._update_ticks()
#    1460     ticks = self.get_major_ticks()
#    1461     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\axis.py:1301, in Axis._update_ticks(self)
#    1299 major_locs = self.get_majorticklocs()
#    1300 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1301 major_ticks = self.get_major_ticks(len(major_locs))
#    1302 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#    1303     tick.update_position(loc)
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\axis.py:1661, in Axis.get_major_ticks(self, numticks)
#    1657     numticks = len(self.get_majorticklocs())
#    1659 while len(self.majorTicks) < numticks:
#    1660     # Update the new tick label properties from the old.
# -> 1661     tick = self._get_tick(major=True)
#    1662     self.majorTicks.append(tick)
#    1663     self._copy_tick_props(self.majorTicks[0], tick)
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\axis.py:1597, in Axis._get_tick(self, major)
#    1593     raise NotImplementedError(
#    1594         f"The Axis subclass {self.__class__.__name__} must define "
#    1595         "_tick_class or reimplement _get_tick()")
#    1596 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1597 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\axis.py:398, in XTick.__init__(self, *args, **kwargs)
#     397 def __init__(self, *args, **kwargs):
# --> 398     super().__init__(*args, **kwargs)
#     399     # x in data coords, y in axes coords
#     400     ax = self.axes
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\axis.py:187, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, labelfontfamily, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     178 self.label1 = mtext.Text(
#     179     np.nan, np.nan,
#     180     fontsize=labelsize, color=labelcolor, visible=label1On,
#     181     fontfamily=labelfontfamily, rotation=self._labelrotation[1])
#     182 self.label2 = mtext.Text(
#     183     np.nan, np.nan,
#     184     fontsize=labelsize, color=labelcolor, visible=label2On,
#     185     fontfamily=labelfontfamily, rotation=self._labelrotation[1])
# --> 187 self._apply_tickdir(tickdir)
#     189 for artist in [self.tick1line, self.tick2line, self.gridline,
#     190                self.label1, self.label2]:
#     191     self._set_artist_props(artist)
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\axis.py:430, in XTick._apply_tickdir(self, tickdir)
#     428 mark1, mark2 = _MARKER_DICT[self._tickdir]
#     429 self.tick1line.set_marker(mark1)
# --> 430 self.tick2line.set_marker(mark2)
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\lines.py:1199, in Line2D.set_marker(self, marker)
#    1188 @_docstring.interpd
#    1189 def set_marker(self, marker):
#    1190     """
#    1191     Set the line marker.
#    1192
#    (...)
#    1197         arguments.
#    1198     """
# -> 1199     self._marker = MarkerStyle(marker, self._marker.get_fillstyle())
#    1200     self.stale = True
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\markers.py:248, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     246 self._user_joinstyle = JoinStyle(joinstyle) if joinstyle is not None else None
#     247 self._set_fillstyle(fillstyle)
# --> 248 self._set_marker(marker)
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\markers.py:334, in MarkerStyle._set_marker(self, marker)
#     332 if not isinstance(marker, MarkerStyle):
#     333     self._marker = marker
# --> 334     self._recache()
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\markers.py:264, in MarkerStyle._recache(self)
#     260 # Initial guess: Assume the marker is filled unless the fillstyle is
#     261 # set to 'none'. The marker function will override this for unfilled
#     262 # markers.
#     263 self._filled = self._fillstyle != 'none'
# --> 264 self._marker_function()
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\markers.py:771, in MarkerStyle._set_tickup(self)
#     770 def _set_tickup(self):
# --> 771     self._transform = Affine2D().scale(1.0, 1.0)
#     772     self._snap_threshold = 1.0
#     773     self._filled = False
#
# File c:\Users\hashe\OneDrive - American University of Beirut\Desktop\AUB CSE\E3\TexasAM-AISchool\Project\ML-KnowledgeDistillation\Venv\Lib\site-packages\matplotlib\transforms.py:1913, in Affine2D.__init__(self, matrix, **kwargs)
#    1910 if matrix is None:
#    1911     # A bit faster than np.identity(3).
#    1912     matrix = IdentityTransform._mtx
# -> 1913 self._mtx = matrix.copy()
#    1914 self._invalid = 0
#
# KeyboardInterrupt:

# %% [markdown]
# ## **Preprocess and Splitting**

# %%
def normalize(x):
    x = x.astype('float32')
    x = x/255.0
    return x

datagen = ImageDataGenerator(
                            rotation_range=15,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            horizontal_flip=True,
)

# %%
from sklearn.model_selection import train_test_split
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size = 0.5, random_state = 0)

# %%
x_train = normalize(x_train)
x_test = normalize(x_test)
x_val = normalize(x_val)

y_train = tf.keras.utils.to_categorical(y_train , 10)
y_test = tf.keras.utils.to_categorical(y_test , 10)
y_val  = tf.keras.utils.to_categorical(y_val , 10)

datagen.fit(x_train)

# %%
print(x_train.shape)
print(y_train.shape)
print(y_test.shape)
print(y_val.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)
# (5000, 10)
# (5000, 10)

# %% [markdown]
# ## **Graph**

# %%
def results(model):
  epoch = 50

  epoch_range = range(1, epoch+1)
  plt.plot(epoch_range, history.history['accuracy'])
  plt.plot(epoch_range, history.history['val_accuracy'])
  plt.title('Classification Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='lower right')
  plt.savefig("Classification Accuracy")
  plt.show()

  # Plot training & validation loss values
  plt.plot(epoch_range,history.history['loss'])
  plt.plot(epoch_range, history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='lower right')
  plt.savefig("Model loss")
  plt.show()

# %% [markdown]
# ##**Model**

# %%
division_factor = 4
weight_decay = 1e-4
model = Sequential([
                    Conv2D(64//division_factor, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), input_shape=(32, 32, 3)),
                    BatchNormalization(),
                    Conv2D(64//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.2),

                    Conv2D(128//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    Conv2D(128//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.3),

                    Conv2D(256//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    Conv2D(256//division_factor, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.4),

                    Flatten(),
                    Dense(256, activation='relu'),
                    BatchNormalization(),
                    Dropout(0.5),
                    Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 16)        448
#
#  batch_normalization (Batch  (None, 32, 32, 16)        64
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 16)        2320
#
#  batch_normalization_1 (Bat  (None, 32, 32, 16)        64
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 16)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 16)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 32)        4640
#
#  batch_normalization_2 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 32)        9248
#
#  batch_normalization_3 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 32)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 32)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          18496
#
#  batch_normalization_4 (Bat  (None, 8, 8, 64)          256
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 64)          36928
#
#  batch_normalization_5 (Bat  (None, 8, 8, 64)          256
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 64)          0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 256)               262400
#
#  batch_normalization_6 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 338970 (1.29 MB)
# Trainable params: 338010 (1.29 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %%
opt =    tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
callbacks = [ ReduceLROnPlateau(monitor='val_loss',
                                patience=10,
                                cooldown=1,
                                verbose=1),
              EarlyStopping(monitor='val_loss',
                            min_delta=1e-4,
                            patience=15)]

# %%
epoch = 50
history = model.fit(datagen.flow(x_train , y_train , batch_size = 64), epochs = epoch, steps_per_epoch=len(x_train)//64, validation_data = (x_val , y_val) , verbose = 1, callbacks=callbacks)
# Out:
# Epoch 1/50
# 781/781 [==============================] - 45s 44ms/step - loss: 1.8775 - accuracy: 0.3677 - val_loss: 1.4345 - val_accuracy: 0.4978 - lr: 0.0010
# Epoch 2/50
# 781/781 [==============================] - 31s 40ms/step - loss: 1.3746 - accuracy: 0.5105 - val_loss: 1.1464 - val_accuracy: 0.6098 - lr: 0.0010
# Epoch 3/50
# 781/781 [==============================] - 32s 41ms/step - loss: 1.2252 - accuracy: 0.5667 - val_loss: 1.0329 - val_accuracy: 0.6440 - lr: 0.0010
# Epoch 4/50
# 781/781 [==============================] - 32s 41ms/step - loss: 1.1250 - accuracy: 0.6102 - val_loss: 1.0849 - val_accuracy: 0.6500 - lr: 0.0010
# Epoch 5/50
# 781/781 [==============================] - 34s 43ms/step - loss: 1.0672 - accuracy: 0.6307 - val_loss: 1.0676 - val_accuracy: 0.6362 - lr: 0.0010
# Epoch 6/50
# 781/781 [==============================] - 34s 44ms/step - loss: 1.0182 - accuracy: 0.6512 - val_loss: 0.9779 - val_accuracy: 0.6810 - lr: 0.0010
# Epoch 7/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.9892 - accuracy: 0.6633 - val_loss: 0.9788 - val_accuracy: 0.6774 - lr: 0.0010
# Epoch 8/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.9543 - accuracy: 0.6770 - val_loss: 1.1010 - val_accuracy: 0.6510 - lr: 0.0010
# Epoch 9/50
# 781/781 [==============================] - 31s 39ms/step - loss: 0.9238 - accuracy: 0.6910 - val_loss: 0.7818 - val_accuracy: 0.7406 - lr: 0.0010
# Epoch 10/50
# 781/781 [==============================] - 31s 39ms/step - loss: 0.9028 - accuracy: 0.6986 - val_loss: 0.7512 - val_accuracy: 0.7586 - lr: 0.0010
# Epoch 11/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.8895 - accuracy: 0.7048 - val_loss: 0.7620 - val_accuracy: 0.7470 - lr: 0.0010
# Epoch 12/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.8764 - accuracy: 0.7100 - val_loss: 0.8139 - val_accuracy: 0.7350 - lr: 0.0010
# Epoch 13/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.8621 - accuracy: 0.7167 - val_loss: 0.7776 - val_accuracy: 0.7496 - lr: 0.0010
# Epoch 14/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.8447 - accuracy: 0.7241 - val_loss: 0.8099 - val_accuracy: 0.7398 - lr: 0.0010
# Epoch 15/50
# 781/781 [==============================] - 34s 43ms/step - loss: 0.8446 - accuracy: 0.7251 - val_loss: 0.7196 - val_accuracy: 0.7754 - lr: 0.0010
# Epoch 16/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.8365 - accuracy: 0.7292 - val_loss: 0.7870 - val_accuracy: 0.7604 - lr: 0.0010
# Epoch 17/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.8313 - accuracy: 0.7302 - val_loss: 0.8024 - val_accuracy: 0.7496 - lr: 0.0010
# Epoch 18/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.8199 - accuracy: 0.7359 - val_loss: 0.7370 - val_accuracy: 0.7700 - lr: 0.0010
# Epoch 19/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.8157 - accuracy: 0.7387 - val_loss: 0.7478 - val_accuracy: 0.7658 - lr: 0.0010
# Epoch 20/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.8094 - accuracy: 0.7402 - val_loss: 0.7557 - val_accuracy: 0.7698 - lr: 0.0010
# Epoch 21/50
# 781/781 [==============================] - 33s 42ms/step - loss: 0.8018 - accuracy: 0.7438 - val_loss: 0.7062 - val_accuracy: 0.7878 - lr: 0.0010
# Epoch 22/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.7915 - accuracy: 0.7483 - val_loss: 0.6421 - val_accuracy: 0.8034 - lr: 0.0010
# Epoch 23/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.7891 - accuracy: 0.7485 - val_loss: 0.6893 - val_accuracy: 0.7884 - lr: 0.0010
# Epoch 24/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.7827 - accuracy: 0.7543 - val_loss: 0.8224 - val_accuracy: 0.7478 - lr: 0.0010
# Epoch 25/50
# 781/781 [==============================] - 33s 42ms/step - loss: 0.7809 - accuracy: 0.7536 - val_loss: 0.7066 - val_accuracy: 0.7840 - lr: 0.0010
# Epoch 26/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.7842 - accuracy: 0.7524 - val_loss: 0.6417 - val_accuracy: 0.8054 - lr: 0.0010
# Epoch 27/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.7759 - accuracy: 0.7576 - val_loss: 0.7521 - val_accuracy: 0.7754 - lr: 0.0010
# Epoch 28/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.7727 - accuracy: 0.7577 - val_loss: 0.7395 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 29/50
# 781/781 [==============================] - 32s 40ms/step - loss: 0.7701 - accuracy: 0.7584 - val_loss: 0.6629 - val_accuracy: 0.8014 - lr: 0.0010
# Epoch 30/50
# 781/781 [==============================] - 33s 42ms/step - loss: 0.7676 - accuracy: 0.7605 - val_loss: 0.6961 - val_accuracy: 0.7890 - lr: 0.0010
# Epoch 31/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.7673 - accuracy: 0.7598 - val_loss: 0.6778 - val_accuracy: 0.7934 - lr: 0.0010
# Epoch 32/50
# 781/781 [==============================] - 34s 43ms/step - loss: 0.7692 - accuracy: 0.7574 - val_loss: 0.6785 - val_accuracy: 0.7960 - lr: 0.0010
# Epoch 33/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.7561 - accuracy: 0.7640 - val_loss: 0.6387 - val_accuracy: 0.8056 - lr: 0.0010
# Epoch 34/50
# 781/781 [==============================] - 32s 40ms/step - loss: 0.7579 - accuracy: 0.7638 - val_loss: 0.8012 - val_accuracy: 0.7526 - lr: 0.0010
# Epoch 35/50
# 781/781 [==============================] - 32s 40ms/step - loss: 0.7494 - accuracy: 0.7686 - val_loss: 0.6303 - val_accuracy: 0.8140 - lr: 0.0010
# Epoch 36/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.7509 - accuracy: 0.7661 - val_loss: 0.6494 - val_accuracy: 0.8026 - lr: 0.0010
# Epoch 37/50
# 781/781 [==============================] - 33s 42ms/step - loss: 0.7509 - accuracy: 0.7666 - val_loss: 0.6590 - val_accuracy: 0.8004 - lr: 0.0010
# Epoch 38/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.7464 - accuracy: 0.7707 - val_loss: 0.6845 - val_accuracy: 0.7976 - lr: 0.0010
# Epoch 39/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.7463 - accuracy: 0.7671 - val_loss: 0.7502 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 40/50
# 781/781 [==============================] - 33s 43ms/step - loss: 0.7477 - accuracy: 0.7674 - val_loss: 0.6998 - val_accuracy: 0.7882 - lr: 0.0010
# Epoch 41/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.7419 - accuracy: 0.7683 - val_loss: 0.6419 - val_accuracy: 0.8100 - lr: 0.0010
# Epoch 42/50
# 781/781 [==============================] - 32s 42ms/step - loss: 0.7439 - accuracy: 0.7704 - val_loss: 0.6907 - val_accuracy: 0.7910 - lr: 0.0010
# Epoch 43/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.7411 - accuracy: 0.7706 - val_loss: 0.7158 - val_accuracy: 0.7882 - lr: 0.0010
# Epoch 44/50
# 781/781 [==============================] - 32s 40ms/step - loss: 0.7387 - accuracy: 0.7728 - val_loss: 0.6647 - val_accuracy: 0.8016 - lr: 0.0010
# Epoch 45/50
# 780/781 [============================>.] - ETA: 0s - loss: 0.7323 - accuracy: 0.7754
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 781/781 [==============================] - 32s 42ms/step - loss: 0.7325 - accuracy: 0.7753 - val_loss: 0.6467 - val_accuracy: 0.8048 - lr: 0.0010
# Epoch 46/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.7039 - accuracy: 0.7830 - val_loss: 0.6163 - val_accuracy: 0.8140 - lr: 1.0000e-04
# Epoch 47/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.6803 - accuracy: 0.7922 - val_loss: 0.6020 - val_accuracy: 0.8212 - lr: 1.0000e-04
# Epoch 48/50
# 781/781 [==============================] - 34s 43ms/step - loss: 0.6777 - accuracy: 0.7920 - val_loss: 0.6176 - val_accuracy: 0.8166 - lr: 1.0000e-04
# Epoch 49/50
# 781/781 [==============================] - 31s 40ms/step - loss: 0.6724 - accuracy: 0.7959 - val_loss: 0.5832 - val_accuracy: 0.8278 - lr: 1.0000e-04
# Epoch 50/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.6738 - accuracy: 0.7949 - val_loss: 0.5941 - val_accuracy: 0.8238 - lr: 1.0000e-04

# %% [markdown]
# ## **Results and Save**

# %%
acc = model.evaluate(x_test , y_test)
print("test set loss : " , acc[0])
print("test set accuracy :", acc[1]*100)
# Out:
# 157/157 [==============================] - 1s 8ms/step - loss: 0.6014 - accuracy: 0.8232
# test set loss :  0.6014456748962402
# test set accuracy : 82.3199987411499

# %%
results(model)

# %%
model.save("CNN-91.74.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
